# %% [markdown]
# <!--Información del curso-->
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/banner_dl.png">

# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0"> Caso de estudio: Juegos Olimpicos  </h1></center>
#
# <center><h2 style="font-size:2em;color:#840700">  Pandas   </h4></center>
#
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/juegos_olimpicos.jpg" align="left" style="width:500px"/></td>
# <td>
#
# Los Juegos Olímpicos, también conocidos como Olimpiadas, son un importante evento deportivo internacional que se celebra cada cuatro años, reuniendo a atletas de todo el mundo para competir en diversas disciplinas deportivas.
#
#
# <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Librerías
#
# Cargando las bibliotecas que necesitamos

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # Datos
# * Revisar las primeras líneas de los archivos
# * Utilizar las funciones de descripción e información para recopilar información estadística, tipos de datos, nombres de columnas y otra información.

# %%
#Cargar el archivo datos/athlete_events.csv en un dataframe llamado df_atletas
df_atletas = pd.DataFrame(pd.read_csv('datos/athlete_events.csv'))

# %%
#Revisar las primeras líneas de los archivos
df_atletas.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
# Encontrar los principales valores estadísticos 
df_atletas.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
#Cargar el archivo datos/datasets_31029_40943_noc_regions.csv en un dataframe llamado df_paises
df_paises = pd.DataFrame(pd.read_csv('datos/datasets_31029_40943_noc_regions.csv'))

# %%
#Mostrar las primeras líneas
df_paises.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %% [markdown]
# ### 1 . Combinando los dataframes
# Combinar los dataframes **df_paises** y **df_atletas** en un dataframe llamado **df**.
#
# *Utilizar la columna 'NOC'*

# %%
#Utilizar pd.merge
df = pd.merge(df_atletas, df_paises, on='NOC')

# %%
#Mostrar las primeras líneas
df.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal region  \
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN  China
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN  China
#
#   notes
# 0   NaN
# 1   NaN

# %% [markdown]
# ### 2. Dataframe de medallas de oro
# Crear un dataframe solo de medallas de oro

# %%
#Mostrar los posibles valores  de la columna Medal
df['Medal'].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
#Crear el dataframe df_MedallasOro solo con ganadores de medallas de oro.
df_MedallasOro = df[df['Medal'] == 'Gold']
df_MedallasOro
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270632  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 270660  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 270667  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 270700  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 270727  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
#                   Team  NOC        Games  Year  Season         City  \
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris
# 42             Finland  FIN  1948 Summer  1948  Summer       London
# 44             Finland  FIN  1948 Summer  1948  Summer       London
# 48             Finland  FIN  1948 Summer  1948  Summer       London
# 60              Norway  NOR  1992 Winter  1992  Winter  Albertville
# ...                ...  ...          ...   ...     ...          ...
# 270632         Georgia  GEO  2004 Summer  2004  Summer       Athina
# 270660         Germany  GER  2004 Summer  2004  Summer       Athina
# 270667     Netherlands  NED  1996 Summer  1996  Summer      Atlanta
# 270700     Netherlands  NED  1996 Summer  1996  Summer      Atlanta
# 270727    Soviet Union  URS  1952 Summer  1952  Summer     Helsinki
#
#                 Sport                             Event Medal       region  \
# 3          Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold      Denmark
# 42         Gymnastics  Gymnastics Men's Team All-Around  Gold      Finland
# 44         Gymnastics      Gymnastics Men's Horse Vault  Gold      Finland
# 48         Gymnastics  Gymnastics Men's Pommelled Horse  Gold      Finland
# 60      Alpine Skiing       Alpine Skiing Men's Super G  Gold       Norway
# ...               ...                               ...   ...          ...
# 270632           Judo           Judo Men's Middleweight  Gold      Georgia
# 270660         Hockey             Hockey Women's Hockey  Gold      Germany
# 270667     Volleyball       Volleyball Men's Volleyball  Gold  Netherlands
# 270700         Rowing         Rowing Men's Coxed Eights  Gold  Netherlands
# 270727      Athletics        Athletics Women's Shot Put  Gold       Russia
#
#        notes
# 3        NaN
# 42       NaN
# 44       NaN
# 48       NaN
# 60       NaN
# ...      ...
# 270632   NaN
# 270660   NaN
# 270667   NaN
# 270700   NaN
# 270727   NaN
#
# [13371 rows x 17 columns]

# %% [markdown]
# #####  Distribución de edades de medallas de oro

# %%
# Revisar si la columna Age tiene elementos nulos 
df_MedallasOro['Age'].isnull().sum()
# Out:
# np.int64(148)

# %%
#Revisar los diferentes valores de Age
df_MedallasOro['Age'].unique()
# Out:
# array([34., 28., 20., 30., 27., 31., 25., 21., 23., 22., 38., 29., 26.,
#        35., 15., 19., 24., 33., 45., 16., 18., nan, 49., 40., 39., 32.,
#        41., 17., 44., 54., 46., 56., 36., 37., 42., 47., 43., 52., 14.,
#        48., 50., 13., 57., 53., 59., 63., 64., 51., 60., 55., 58.])

# %%
# Eliminar las filas con 'nan' 
df_MedallasOro = df_MedallasOro.dropna(subset=['Age'])

# %%
#Mostrar nuevamente los posibles valores de la columna 'Age'
df_MedallasOro['Age'].unique()
# Out:
# array([34., 28., 20., 30., 27., 31., 25., 21., 23., 22., 38., 29., 26.,
#        35., 15., 19., 24., 33., 45., 16., 18., 49., 40., 39., 32., 41.,
#        17., 44., 54., 46., 56., 36., 37., 42., 47., 43., 52., 14., 48.,
#        50., 13., 57., 53., 59., 63., 64., 51., 60., 55., 58.])

# %%
#Mostrar un histograma de la columna 'Age' con 20 bins
df_MedallasOro['Age'].hist(bins=20)
# Out:
# <Axes: >

# %%
# ¿Cuantas personas mayores a 50 han ganado una medalla de oro?
(df_MedallasOro['Age'] > 50).sum()
# Out:
# np.int64(65)

# %% [markdown]
# ##### ¿Qué disciplinas te permiten conseguir una medalla de oro después de los cincuenta?

# %%
#Mostrar las diferentes disciplinas (mayores a 50)
df_MedallasOro[df_MedallasOro['Age']>50]['Sport'].unique()
# Out:
# array(['Equestrianism', 'Sailing', 'Alpinism', 'Art Competitions',
#        'Curling', 'Roque', 'Shooting', 'Archery', 'Croquet'], dtype=object)

# %%
#Mostrar el número de ganadores por disciplina (mayores a 50)
df_MedallasOro[df_MedallasOro['Age'] > 50]['Sport'].value_counts()
# Out:
# Sport
# Equestrianism       18
# Sailing             12
# Shooting            11
# Archery             11
# Art Competitions     8
# Curling              2
# Alpinism             1
# Roque                1
# Croquet              1
# Name: count, dtype: int64

# %% [markdown]
# ### 3. Mujeres en atletismo

# %%
# Crear un dataframe para mujeres llamado df_women 
# Considerar solamente los juegos de verano

df_women = df[(df['Sex'] == 'F') & (df['Season'] == 'Summer')]
df_women
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 26           8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27           8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 32          13                   Minna Maarit Aalto   F  30.0   159.0    55.5
# 33          13                   Minna Maarit Aalto   F  34.0   159.0    55.5
# 79          21            Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 270731  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 270750  135560                    Stavroula Zygouri   F  36.0   171.0    63.0
# 270753  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 270754  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
# 270761  135568               Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                 Team  NOC        Games  Year  Season            City  \
# 26       Netherlands  NED  1932 Summer  1932  Summer     Los Angeles
# 27       Netherlands  NED  1932 Summer  1932  Summer     Los Angeles
# 32           Finland  FIN  1996 Summer  1996  Summer         Atlanta
# 33           Finland  FIN  2000 Summer  2000  Summer          Sydney
# 79            Norway  NOR  2008 Summer  2008  Summer         Beijing
# ...              ...  ...          ...   ...     ...             ...
# 270731  Soviet Union  URS  1964 Summer  1964  Summer           Tokyo
# 270750        Greece  GRE  2004 Summer  2004  Summer          Athina
# 270753        Russia  RUS  2000 Summer  2000  Summer          Sydney
# 270754        Russia  RUS  2004 Summer  2004  Summer          Athina
# 270761       Belarus  BLR  2016 Summer  2016  Summer  Rio de Janeiro
#
#              Sport                                      Event   Medal  \
# 26       Athletics               Athletics Women's 100 metres     NaN
# 27       Athletics     Athletics Women's 4 x 100 metres Relay     NaN
# 32         Sailing                 Sailing Women's Windsurfer     NaN
# 33         Sailing                 Sailing Women's Windsurfer     NaN
# 79        Handball                  Handball Women's Handball    Gold
# ...            ...                                        ...     ...
# 270731   Athletics                 Athletics Women's Shot Put  Bronze
# 270750   Wrestling  Wrestling Women's Middleweight, Freestyle     NaN
# 270753   Athletics     Athletics Women's 4 x 400 metres Relay  Bronze
# 270754   Athletics     Athletics Women's 4 x 400 metres Relay  Silver
# 270761  Basketball              Basketball Women's Basketball     NaN
#
#              region notes
# 26      Netherlands   NaN
# 27      Netherlands   NaN
# 32          Finland   NaN
# 33          Finland   NaN
# 79           Norway   NaN
# ...             ...   ...
# 270731       Russia   NaN
# 270750       Greece   NaN
# 270753       Russia   NaN
# 270754       Russia   NaN
# 270761      Belarus   NaN
#
# [59314 rows x 17 columns]

# %%
#Crear un gráfico en el que colocamos el año (en el eje x) 
# y contamos el número de participantes por edición de los juegos 
df_women['Year'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
#Revisar el numero de participantes mujeres en 2016
len(df_women[df_women['Year'] == 2016])
# Out:
# 6203

# %%
#Revisar el numero de participantes mujeres en 2016 con medalla de oro
df_women[(df_women['Year'] == 2016) & (df_women['Medal'] == 'Gold')]
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 1493       832            Nicola Virginia Adams   F  33.0   164.0    51.0
# 3017      1682                Morolake Akinosun   F  22.0   163.0    61.0
# 6554      3672                      milie Andol   F  28.0   170.0    97.0
# 8067      4466              Giselle Anne Ansley   F  24.0   176.0    73.0
# 8957      4928           Katie Louise Archibald   F  22.0   178.0    70.0
# ...        ...                              ...  ..   ...     ...     ...
# 268511  134516                    Zhang Mengxue   F  25.0   162.0    70.0
# 268929  134740                     Zheng Shuyin   F  22.0   188.0    75.0
# 268964  134759  Viktoriya Yuryevna Zhilinskayte   F  27.0   188.0    80.0
# 269020  134783                    Zhong Tianshi   F  25.0   168.0    62.0
# 269162  134857                         Zhu Ting   F  21.0   198.0    78.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 1493    Great Britain  GBR  2016 Summer  2016  Summer  Rio de Janeiro
# 3017    United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 6554           France  FRA  2016 Summer  2016  Summer  Rio de Janeiro
# 8067    Great Britain  GBR  2016 Summer  2016  Summer  Rio de Janeiro
# 8957    Great Britain  GBR  2016 Summer  2016  Summer  Rio de Janeiro
# ...               ...  ...          ...   ...     ...             ...
# 268511          China  CHN  2016 Summer  2016  Summer  Rio de Janeiro
# 268929          China  CHN  2016 Summer  2016  Summer  Rio de Janeiro
# 268964         Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro
# 269020          China  CHN  2016 Summer  2016  Summer  Rio de Janeiro
# 269162          China  CHN  2016 Summer  2016  Summer  Rio de Janeiro
#
#              Sport                                   Event Medal  region notes
# 1493        Boxing                Boxing Women's Flyweight  Gold      UK   NaN
# 3017     Athletics  Athletics Women's 4 x 100 metres Relay  Gold     USA   NaN
# 6554          Judo                Judo Women's Heavyweight  Gold  France   NaN
# 8067        Hockey                   Hockey Women's Hockey  Gold      UK   NaN
# 8957       Cycling            Cycling Women's Team Pursuit  Gold      UK   NaN
# ...            ...                                     ...   ...     ...   ...
# 268511    Shooting  Shooting Women's Air Pistol, 10 metres  Gold   China   NaN
# 268929   Taekwondo           Taekwondo Women's Heavyweight  Gold   China   NaN
# 268964    Handball               Handball Women's Handball  Gold  Russia   NaN
# 269020     Cycling             Cycling Women's Team Sprint  Gold   China   NaN
# 269162  Volleyball           Volleyball Women's Volleyball  Gold   China   NaN
#
# [318 rows x 17 columns]

# %% [markdown]
# ### 4. Medallas de oro por país

# %%
# Encontrar los cinco países con mayor número de medallas de oro 
df_MedallasOro['region'].value_counts().head()
# Out:
# region
# USA        2627
# Russia     1599
# Germany    1293
# UK          657
# Italy       567
# Name: count, dtype: int64

# %% [markdown]
# # Ejercicio
#
# **Parte 1**
#
# Crear un dataframe para México llamado df_Mexico (solo datos de México)

# %% [markdown]
# <div class="alert alert-success">
#
# 1. Mostrar la distribución de edades (frecuencias).
# </div>

# %%
df_mexico = df[df['region'] == 'Mexico']
df_mexico
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 184         82             Enrique Abaroa Martnez   M  26.0   183.0    75.0
# 205         98                      Hctor Abaunza   M  30.0   169.0    75.0
# 206         98                      Hctor Abaunza   M  30.0   169.0    75.0
# 207         98                      Hctor Abaunza   M  30.0   169.0    75.0
# 710        405           Jos Javier Abella Fanjul   M  22.0   176.0    66.0
# ...        ...                                ...  ..   ...     ...     ...
# 268222  134358                 Omar Zepeda de Lon   M  39.0   175.0    70.0
# 268262  134383            Jos Luis Zertuche Chvez   M  27.0   172.0    71.0
# 269378  134967                Pablo Zierold Reyes   M   NaN   173.0     NaN
# 269613  135062  Antonio Lus "Zinha" Naelson Matas   M  28.0   163.0    66.0
# 270433  135421    Goretti Alejandra Zumaya Flores   F  19.0   165.0    65.0
#
#           Team  NOC        Games  Year  Season            City      Sport  \
# 184     Mexico  MEX  2000 Summer  2000  Summer          Sydney     Tennis
# 205     Mexico  MEX  1968 Summer  1968  Summer     Mexico City    Fencing
# 206     Mexico  MEX  1968 Summer  1968  Summer     Mexico City    Fencing
# 207     Mexico  MEX  1968 Summer  1968  Summer     Mexico City    Fencing
# 710     Mexico  MEX  2016 Summer  2016  Summer  Rio de Janeiro   Football
# ...        ...  ...          ...   ...     ...             ...        ...
# 268222  Mexico  MEX  2016 Summer  2016  Summer  Rio de Janeiro  Athletics
# 268262  Mexico  MEX  2000 Summer  2000  Summer          Sydney     Boxing
# 269378  Mexico  MEX  1932 Summer  1932  Summer     Los Angeles   Swimming
# 269613  Mexico  MEX  2004 Summer  2004  Summer          Athina   Football
# 270433  Mexico  MEX  2016 Summer  2016  Summer  Rio de Janeiro   Shooting
#
#                                          Event Medal  region notes
# 184                       Tennis Men's Doubles   NaN  Mexico   NaN
# 205             Fencing Men's Foil, Individual   NaN  Mexico   NaN
# 206                   Fencing Men's Foil, Team   NaN  Mexico   NaN
# 207                  Fencing Men's Sabre, Team   NaN  Mexico   NaN
# 710                    Football Men's Football   NaN  Mexico   NaN
# ...                                        ...   ...     ...   ...
# 268222      Athletics Men's 50 kilometres Walk   NaN  Mexico   NaN
# 268262         Boxing Men's Light-Middleweight   NaN  Mexico   NaN
# 269378  Swimming Men's 200 metres Breaststroke   NaN  Mexico   NaN
# 269613                 Football Men's Football   NaN  Mexico   NaN
# 270433   Shooting Women's Air Rifle, 10 metres   NaN  Mexico   NaN
#
# [2880 rows x 17 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# 2. Mostrar la participación de desportistas mexicanos en las competencias de Verano (frecuencias por año).
# </div>

# %%
df_mexico[df_mexico['Season'] == 'Summer']['Year'].value_counts().sort_index().plot(kind='bar', xlabel='Año', ylabel='Num. Participantes Mexicanos')
# Out:
# <Axes: xlabel='Año', ylabel='Num. Participantes Mexicanos'>

# %% [markdown]
# <div class="alert alert-success">
#
# 3. Encontrar el numero total de medallas de oro, plata y bronce.
# </div>

# %%
df_mexico['Medal'].value_counts()
# Out:
# Medal
# Bronze    54
# Gold      30
# Silver    26
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
#
# 4. Encontrar a los deportistas mexicanos con 2 o más medallas.
# </div>

# %%
df_mexico.groupby('Name')['Medal'].count().sort_values(ascending=False).loc[lambda x: x >= 2]
# Out:
# Name
# Joaqun Capilla Prez                   4
# Humberto Mariles Corts                3
# Mara del Rosario Espinoza Espinoza    3
# Germn Sal Snchez Snchez               2
# Joaqun Prez de las Heras              2
# Paola Milagros Espinosa Snchez        2
# Ral Gonzlez Rodrguez                  2
# Rubn Uriza Castro                     2
# Name: Medal, dtype: int64

# %% [markdown]
# # Ejercicio
#
# **Parte 2**
#
# *Utilizar todos los datos*

# %% [markdown]
# <div class="alert alert-success">
#
# 5. Encontrar a los 5 deportistas con más medallas de oro en los juegos de Verano.
# </div>

# %%
df[(df['Medal'] == 'Gold') & (df['Season'] == 'Summer')]['Name'].value_counts().head()
# Out:
# Name
# Michael Fred Phelps, II               23
# Raymond Clarence "Ray" Ewry           10
# Larysa Semenivna Latynina (Diriy-)     9
# Mark Andrew Spitz                      9
# Frederick Carlton "Carl" Lewis         9
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# 6. Encontrar el deportista (o deportistas) más joven en ganar un medalla de oro, también mencionar: la edad, año de obtención, disciplina y juegos (verano o invierno,).
# </div>

# %%
min_age = df[df['Medal'] == 'Gold']['Age'].min()

df[(df['Medal'] == 'Gold') & (df['Age'] == min_age)][['Name', 'Age', 'Year','Sport', 'Season']]
# Out:
#                                       Name   Age  Year  \
# 27194                        Hans Bourquin  13.0  1928
# 51965   Donna Elizabeth de Varona (-Pinto)  13.0  1960
# 73526                           Fu Mingxia  13.0  1992
# 78483         Marjorie Gestring (-Redlick)  13.0  1936
# 119189                          Kim Yun-Mi  13.0  1994
# 200497       Aileen Muriel Riggin (-Soule)  13.0  1920
# 268259                         Klaus Zerta  13.0  1960
#
#                             Sport  Season
# 27194                      Rowing  Summer
# 51965                    Swimming  Summer
# 73526                      Diving  Summer
# 78483                      Diving  Summer
# 119189  Short Track Speed Skating  Winter
# 200497                     Diving  Summer
# 268259                     Rowing  Summer

# %% [markdown]
# <div class="alert alert-success">
#
# 7. ¿Qué deporte (sport) ha tenido el mayor número de participantes  en toda su historia (contando solo lo reportado en el archivo)?
#
# </div>

# %%
df.groupby('Sport')['Name'].count().idxmax()
# Out:
# 'Athletics'
