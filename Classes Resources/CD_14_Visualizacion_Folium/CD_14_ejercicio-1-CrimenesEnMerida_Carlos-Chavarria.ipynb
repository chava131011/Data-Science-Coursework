# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <br><br><center><h1 style="font-size:2em;color:#2467C0"> Ejericicio 1: Crimenes en la ciudad de Mérida (Ficticio)  </h1></center>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/policia.jpeg" align="middle" style="width:550px"/></td>
# <td>
#
# La Fiscalía General del Estado informó que al día en promedio en Yucatán se registran ocho robos en sus diferentes modalidades, aunque la mayor parte de ellos, cerca del 80 por ciento, ocurre en Mérida.
#
# En esta ciudad, las zonas de mayor incidencia son el Poniente, Sur y Centro.
#
# Aunque los casos más sonados, de mayor cuantía en cuanto al botín y que han llamado la atención de los medios, se dijo que se han registrado en el Norte.
#
# https://www.yucatan.com.mx/merida/merida-el-blanco-principal-de-los-robos
#
#  <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Ejercicio

# %% [markdown]
# <div class="alert alert-success">
#
# Con los datos del archivo "asaltos_yucatan.csv", mostrar en un mapa la ubicación de los delitos en Mérida, de ser posible muestre como _popup_ la categoría.
#
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium

# %%
#Cargar el archivo datos/asaltos_yucatan.csv en un DataFrame llamado data
# si es necesario usar la opcion encoding = "ISO-8859-1"
data = pd.read_csv('datos/asaltos_yucatan.csv', encoding = "ISO-8859-1")

# %%
#Mostrar las primeras filas del DataFrame data
data.head()
# Out:
#    NumInc  Categoria              Descripcion   Ciudad          Direccion  \
# 0       1     asalto  robo objetos personales  Tizimín             Centro
# 1       2     asalto  robo objetos personales   Mérida         Calle 53-F
# 2       3     asalto  robo objetos personales   Mérida   Calle 53 791-803
# 3       4     asalto  robo objetos personales   Mérida   Calle 49 808-796
# 4       5  robo casa     robo casa habitacion   Mérida  Calle 51A 784-780
#
#          lat       long
# 0  21.142586 -88.147633
# 1  21.074071 -89.666229
# 2  21.077830 -89.655865
# 3  21.001845 -89.713986
# 4  21.000559 -89.712173

# %%
m = folium.Map(location=(20.97908796686816, -89.62416787988914), zoom_start=12)

for i in data.index:
    folium.Marker(
        location=[data['lat'].loc[i], data['long'].loc[i]],
        tooltip=f'{data['Descripcion'].loc[i]}'
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a69f772017f9f5579c28322f4bceb225 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a69f772017f9f5579c28322f4bceb225&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a69f772017f9f5579c28322f4bceb225 = L.map(
#                 &quot;map_a69f772017f9f5579c28322f4bceb225&quot;,
#                 {
#                     center: [20.97908796686816, -89.62416787988914],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0f3330205847e8222b0760d7e21c26d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a0f3330205847e8222b0760d7e21c26d.addTo(map_a69f772017f9f5579c28322f4bceb225);
#
#
#             var marker_3cee0d229733c0704a34e8fed636e5c5 = L.marker(
#                 [21.142586, -88.147633],
#                 {
# }
#             ).addTo(map_a69f772017f9f5579c28322f4bceb225);
#
#
#             marker_3cee0d229733c0704a34e8fed636e5c5.bindTooltip(
#                 `&lt;div&gt;
#                      robo objetos personales
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_66583b3f25f945db91132117778a20b5 = L.marker(
#                 [21.074071, -89.666229],
#                 {
# }
#             ).addTo(map_a69f772017f9f5579c28322f4bceb225);
#
#
#             marker_66583b3f25f945db91132117778a20b5.bindTooltip(
#                 `&lt;div&gt;
#                      robo objetos personales
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_07268eac058b641a569188ce0cc1939c = L.marker(
#                 [21.07783, -89.655865],
#                 {
# }
#             ).addTo(map_a69f772017f9f5579c28322f4bceb225);
#
#
#             marker_07268eac058b641a569188ce0cc1939c.bindTooltip(
#                 `&lt;div&gt;
#                      robo objetos personales
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_de876267df213fe7a139d2d477e43c42 = L.marker(
#                 [21.001845, -89.713986],
#                 {
# }
#             ).addTo(map_a69f772017f9f5579c28322f4bceb225);
#
#
#             marker_de876267df213fe7a139d2d477e43c42.bindTooltip(
#                 `&lt;div&gt;
#                      robo objetos personales
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5af7ba8382d44e34bd0f6d4fb95ed9ad = L.marker(
#                 [21.000559, -89.712173],
#                 {
# }
#             ).addTo(map_a69f772017f9f5579c28322f4bceb225);
#
#
#             marker_5af7ba8382d44e34bd0f6d4fb95ed9ad.bindTooltip(
#                 `&lt;div&gt;
#                      robo casa habitacion
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0e69b005d550b6b309e7d8f160b42908 = L.marker(
#                 [20.998856, -89.724501],
#                 {
# }
#             ).addTo(map_a69f772017f9f5579c28322f4bceb225);
#
#
#             marker_0e69b005d550b6b309e7d8f160b42908.bindTooltip(
#                 `&lt;div&gt;
#                      robo objetos personales
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_feb47b03c3cb0a124236e47b3ab93d3b = L.marker(
#                 [20.993177, -89.711294],
#                 {
# }
#             ).addTo(map_a69f772017f9f5579c28322f4bceb225);
#
#
#             marker_feb47b03c3cb0a124236e47b3ab93d3b.bindTooltip(
#                 `&lt;div&gt;
#                      robo objetos personales
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_32d36c3cd8cfaf0f8029975190a6a139 = L.marker(
#                 [20.971428, -89.639831],
#                 {
# }
#             ).addTo(map_a69f772017f9f5579c28322f4bceb225);
#
#
#             marker_32d36c3cd8cfaf0f8029975190a6a139.bindTooltip(
#                 `&lt;div&gt;
#                      robo objetos personales
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_8fd0d9fea27fdab6ef526ca416d83922 = L.marker(
#                 [20.963172, -89.631224],
#                 {
# }
#             ).addTo(map_a69f772017f9f5579c28322f4bceb225);
#
#
#             marker_8fd0d9fea27fdab6ef526ca416d83922.bindTooltip
