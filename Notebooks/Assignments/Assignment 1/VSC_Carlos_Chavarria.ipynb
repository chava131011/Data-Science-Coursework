# %% [markdown]
# # Ejemplo Notebook

# %% [markdown]
# ## Se cargan los datos

# %%
#Se importan las librerias
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Leer los datos
data: pd.DataFrame = pd.read_csv("datos/datos.csv")

# %%
#Vista previa de los primeros datos
print(data.head())
# Out:
#        Mes  Ventas  Gastos
# 0    Enero     150     100
# 1  Febrero     200     120
# 2    Marzo     250     180
# 3    Abril     300     200
# 4     Mayo     280     190

# %% [markdown]
# ## Graficar los datos

# %%
#Graficamos
data.plot(x= 'Mes', y='Ventas', kind = 'line')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
